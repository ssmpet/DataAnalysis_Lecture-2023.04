# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

import folium
import requests, json
from urllib.parse import quote 


plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
mpg = sns.load_dataset('mpg')
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.cylinders.value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
mpg.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration
# 0  18.0          8         307.0       130.0    3504          12.0  \
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
mpg.pivot_table('mpg', 'cylinders')
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %%
x = mpg.pivot_table('mpg', 'cylinders')
plt.figure(figsize=(6, 3))
plt.bar(x.index, x.mpg)
plt.title('실린더별 mpg의 평균')
plt.xlabel('실린더')
plt.ylabel('mpg 평균')
plt.show()

# %%
mpg.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration
# 0  18.0          8         307.0       130.0    3504          12.0  \
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg_scatter = mpg[['displacement','horsepower']]

mpg_scatter.shape
# Out:
# (398, 2)

# %%
mpg_scatter.isna().sum()
# Out:
# displacement    0
# horsepower      6
# dtype: int64

# %%
mpg_scatter.horsepower.fillna(mpg_scatter.horsepower.mean(), inplace=True)
# Out:
# C:\Users\YONSAI\AppData\Local\Temp\ipykernel_9792\913432034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpg_scatter.horsepower.fillna(mpg_scatter.horsepower.mean(), inplace=True)

# %%
num = mpg_scatter.count()
num
# Out:
# displacement    398
# horsepower      398
# dtype: int64

# %%
plt.figure(figsize=(6, 5))
plt.scatter(mpg_scatter.displacement, mpg_scatter.horsepower)
plt.title('배기량과 마력의 산점도')
plt.xlabel('배기량')
plt.ylabel('마력')
plt.show()

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration
# 0  18.0          8         307.0       130.0    3504          12.0  \
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['manufacturer'] = mpg.name.apply(lambda x : x.split()[0])
mpg.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration
# 0  18.0          8         307.0       130.0    3504          12.0  \
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name manufacturer
# 0          70    usa  chevrolet chevelle malibu    chevrolet
# 1          70    usa          buick skylark 320        buick
# 2          70    usa         plymouth satellite     plymouth
# 3          70    usa              amc rebel sst          amc
# 4          70    usa                ford torino         ford

# %%
manu_model = mpg.manufacturer.value_counts().head(10)
manu_model.head()
# Out:
# manufacturer
# ford         51
# chevrolet    43
# plymouth     31
# amc          28
# dodge        28
# Name: count, dtype: int64

# %%
manu_mean = mpg.pivot_table('mpg', 'manufacturer').sort_values('mpg', ascending=False).head(10)
manu_mean.head()
# Out:
#                     mpg
# manufacturer
# vw            39.016667
# nissan        36.000000
# triumph       35.000000
# honda         33.761538
# renault       32.880000

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1) 

plt.title('제조사별 모델의 개수(Top 10)')
plt.barh(manu_model.index, manu_model.values)
plt.xlabel('모델의 개수')
plt.ylabel('제조사')

plt.subplot(122)
plt.title('제조사별 mpg의 평균(Top 10)')
plt.barh(manu_mean.index, manu_mean.mpg)
plt.xlabel('mpg의 평균')
plt.show()

# %%
df = pd.read_csv('경기도청사및출장소현황.csv', encoding='euc-kr')
df.head()
# Out:
#          집계일자  시군명   구분명        전화번호안내  소재지우편번호               소재지도로명주소
# 0  2023-03-08  안성시  안성시청  031-678-2114    17586         경기도 안성시 시청길 25  \
# 1  2023-03-08  안성시   고삼면  031-678-3980    17505   경기도 안성시 고삼면 고삼호수로 21
# 2  2023-03-08  안성시   공도읍  031-678-3610    17560         경기도 안성시 공도4로 8
# 3  2023-03-08  안성시   보개면  031-678-3680    17509  경기도 안성시 보개면 보개원삼로 220
# 4  2023-03-08  안성시   금광면  031-678-3710    17536  경기도 안성시 금광면 금광오산로 228
#
#                     소재지지번주소    WGS84위도     WGS84경도
# 0        경기도 안성시 봉산동 31-3번지  37.007357  127.280313
# 1  경기도 안성시 고삼면 가유리 287-11번지  37.082693  127.263456
# 2   경기도 안성시 공도읍 만정리 793-1번지  37.001014  127.172515
# 3    경기도 안성시 보개면 불현리 42-1번지  37.023016  127.290858
# 4    경기도 안성시 금광면 내우리 20-9번지  36.997233  127.317531

# %%
df = df[(df.구분명.str.contains('구청') | df.구분명.str.contains('도청') | df.구분명.str.contains('시청')) & ~(df.구분명.str.contains('별관')) & ~(df.구분명.str.contains('임시')) ]
df.head()
# Out:
#           집계일자  시군명   구분명        전화번호안내  소재지우편번호                    소재지도로명주소
# 0   2023-03-08  안성시  안성시청  031-678-2114    17586              경기도 안성시 시청길 25  \
# 17  2023-02-15  안산시  단원구청  031-481-6000    15396  경기도 안산시 단원구 중앙대로 685 (초지동)
# 22  2023-02-15  안산시  안산시청  031-481-2000    15335   경기도 안산시 단원구 화랑로 387 (고잔동)
# 42  2023-02-15  안산시  상록구청  031-481-5000    15585    경기도 안산시 상록구 석호로 110 (사동)
# 52  2023-02-14  군포시  군포시청  031-392-3000    15829              경기도 군포시 청백리길 6
#
#                     소재지지번주소    WGS84위도     WGS84경도
# 0        경기도 안성시 봉산동 31-3번지  37.007357  127.280313
# 17  경기도 안산시 단원구 초지동 666-2번지  37.320905  126.815245
# 22    경기도 안산시 단원구 고잔동 515번지  37.321956  126.830878
# 42    경기도 안산시 상록구 사동 1585번지  37.300692  126.846368
# 52        경기도 군포시 금정동 844번지  37.361254  126.936150

# %%
df.isna().sum()
# Out:
# 집계일자        0
# 시군명         0
# 구분명         0
# 전화번호안내      1
# 소재지우편번호     0
# 소재지도로명주소    0
# 소재지지번주소     0
# WGS84위도     0
# WGS84경도     0
# dtype: int64

# %%
df['주소'] = df.소재지도로명주소.apply(lambda x: x.split('(')[0].strip())

# %%
df = df[['구분명', '전화번호안내', '주소']]
df.head()
# Out:
#      구분명        전화번호안내                    주소
# 0   안성시청  031-678-2114        경기도 안성시 시청길 25
# 17  단원구청  031-481-6000  경기도 안산시 단원구 중앙대로 685
# 22  안산시청  031-481-2000   경기도 안산시 단원구 화랑로 387
# 42  상록구청  031-481-5000   경기도 안산시 상록구 석호로 110
# 52  군포시청  031-392-3000        경기도 군포시 청백리길 6

# %%
with open('../03.DataAnalysis/04.지도시각화/data/kakaoapikey.txt') as f:
    kakao_key = f.read()

base_url = 'https://dapi.kakao.com/v2/local/search/address.json'
header = {'Authorization': f'KakaoAK {kakao_key}'}

# %%
lat_list, lng_list = [], []

for gov in df.주소:

    url = f'{base_url}?query={quote(gov)}'

    result = requests.get(url, headers=header).json()
    lat_list.append(float(result['documents'][0]['y']))
    lng_list.append(float(result['documents'][0]['x']))     

df['위도'] = lat_list
df['경도'] = lng_list

# %%
df.head()
# Out:
#      구분명        전화번호안내                    주소         위도          경도
# 0   안성시청  031-678-2114        경기도 안성시 시청길 25  37.008308  127.279210
# 17  단원구청  031-481-6000  경기도 안산시 단원구 중앙대로 685  37.319777  126.811755
# 22  안산시청  031-481-2000   경기도 안산시 단원구 화랑로 387  37.322557  126.832714
# 42  상록구청  031-481-5000   경기도 안산시 상록구 석호로 110  37.301335  126.846410
# 52  군포시청  031-392-3000        경기도 군포시 청백리길 6  37.361023  126.935316

# %%
df['청구분'] = df.구분명.apply(lambda x: (x.split('청')[0][-1]+'청'))

# %%
g_map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=9)
for i in df.index:
    pushpin_col = folium.CustomIcon(f'{df.청구분[i]}.png', icon_size=(40, 40))

    folium.Marker(
        location=[df.위도[i], df.경도[i]], 
        popup=folium.Popup(df.전화번호안내[i], max_width=200),
        tooltip=df.구분명[i],
        icon=pushpin_col
    ).add_to(g_map)

title_html = '<h3 align="center" style="font-size:20px;">경기도청사 및 출장소 현황</h3>'
g_map.get_root().html.add_child(folium.Element(title_html))
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19b49382cea88e8e61815d9c77a163f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px;&quot;&gt;경기도청사 및 출장소 현황&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19b49382cea88e8e61815d9c77a163f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19b49382cea88e8e61815d9c77a163f3 = L.map(
#                 &quot;map_19b49382cea88e8e61815d9c77a163f3&quot;,
#                 {
#                     center: [37.425845550715074, 127.03308677437805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5d7f395d839800b77502db4b12a30a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19b49382cea88e8e61815d9c77a163f3);
#
#
#             var marker_7972ab6e6b708751490712b9d0388b6a = L.marker(
#                 [37.0083078624137, 127.279209977315],
#                 {}
#             ).addTo(map_19b49382cea88e8e61815d9c77a163f3);
#
#
#         var custom_icon_25577c72acc847858b206f4f50695773 = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_7972ab6e6b708751490712b9d0388b6a.setIcon(custom_icon_25577c72acc847858b206f4f50695773);
#
#
#         var popup_d46f5297ef416c32d9d02d8da586fe32 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_00b38b082ef52551111fbcc84e1b0adf = $(`&lt;div id=&quot;html_00b38b082ef52551111fbcc84e1b0adf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;031-678-2114&lt;/div&gt;`)[0];
#                 popup_d46f5297ef416c32d9d02d8da586fe32.setContent(html_00b38b082ef52551111fbcc84e1b0adf);
#
#
#
#         marker_7972ab6e6b708751490712b9d0388b6a.bindPopup(popup_d46f5297ef416c32d9d02d8da586fe32)
#         ;
#
#
#
#
#             marker_7972ab6e6b708751490712b9d0388b6a.bindTooltip(
#                 `&lt;div&gt;
#                      안성시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0017f9b3b81c667692ce48e8ab36219 = L.marker(
#                 [37.3197767270487, 126.811754995919],
#                 {}
#             ).addTo(map_19b49382cea88e8e61815d9c77a163f3);
#
#
#         var custom_icon_c4fff4212b66815cca827aadc8ea141c = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_b0017f9b3b81c667692ce48e8ab36219.setIcon(custom_icon_c4fff4212b66815cca827aadc8ea141c);
#
#
#         var popup_c0e49f0274c57cddee8f6daf2a0b6d99 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_37c1312629b317af1c5343268b1c2c8c = $(`&lt;div id=&quot;html_37c1312629b317af1c5343268b1c2c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;031-481-6000&lt;/div&gt;`)[0];
#                 popup_c0e49f0274c57cddee8f6daf2a0b6d99.setContent(html_37c1312629b317af1c5343268b1c2c8c);
#
#
#
#         marker_b0017f9b3b81c667692ce48e8ab36219.bindPopup(popup_c0e49f0274c57cddee8f6daf2a0b6d99)
#         ;
#
#
#
#
#             marker_b0017f9b3b81c667692ce48e8ab36219.bindTooltip(
#                 `&lt;div&gt;
#                      단원구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d740e86c9e1d5238567d4f1c3d4009c0 = L.marker(
#                 [37.3225569017972, 126.83271351583],
#                 {}
#             ).addTo(map_19b49382cea88e8e61815d9c77a163f3);
#
#
#         var custom_icon_157d8925534b7a297dda7d62365b37a8 = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_d740e86c9e1d5238567d4f1c3d4009c0.setIcon(custom_icon_157d8925534b7a297dda7d62365b37a8);
#
#
#         var popup_e8016952b826cffb8b6e16e14e4a5d78 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_14e971935416a084325119e4b425c5d7 = $(`&lt;div id=&quot;html_14e971935416a084325119e4b425c5d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;031-481-2000&lt;/div&gt;`)[0];
#                 popup_e8016952b826cffb8b6e16e14e4a5d78.setContent(html_14e971935416a084325119e4b425c5d7);
#
#
#
#         marker_d740e86c9e1d5238567d4f1c3d4009c0.bindPopup(popup_e8016952b826cffb8b6e16e14e4a5d78)
#         ;
#
#
#
#
#             marker_d740e86c9e1d5238567d4f1c3d4009c0.bindTooltip(
#                 `&lt;div&gt;
#                      안산시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b3daf6025804e724be63ad195a09d4ac = L.marker(
#                 [37
