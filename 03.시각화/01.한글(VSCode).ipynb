# %% [markdown]
# ### Matplotlib 한글 사용 - VSCode

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.5.2'

# %% [markdown]
# - 라인 플롯

# %%
plt.plot([0,1,2,3], [0,1,4,9])  # X, Y 
plt.title('Line Plot')          # 제목
plt.grid()                      # 젹자선
plt.show()

# %%
plt.plot([0,1,2,3], [0,1,4,9]) # X, Y 
plt.title('라인 플롯')          # 제목
plt.grid()                     # 젹자선
plt.show()

# %% [markdown]
# - 가장 쉬운 방법

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.plot([0,1,2,3], [0,1,4,9]) # X, Y 
plt.title('라인 플롯')          # 제목
plt.grid()                     # 젹자선
plt.show()

# %% [markdown]
# - 다양한 폰트를 설정하는 방법

# %%
import matplotlib.font_manager as fm

path = 'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts' 
font_list = fm.findSystemFonts(fontpaths=path, fontext='ttf')

# %%
font_list
# Out:
# ['C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicLight.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundEB.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjoBold.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicExtraBold.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjo.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundL.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-all.ttc',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjoExtraBold.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundR.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic.ttf',
#  'C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicBold.ttf',
# ...

# %%
fm.FontProperties(fname='C:\\Users\\sujung\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-all.ttc').get_name()
# Out:
# 'D2Coding'

# %%
[fm.FontProperties(fname=font).get_name() for font in font_list if 'Nanum' in font]
# Out:
# ['NanumGothic',
#  'NanumSquareRound',
#  'NanumMyeongjo',
#  'NanumGothic',
#  'NanumMyeongjo',
#  'NanumSquareRound',
#  'NanumMyeongjo',
#  'NanumSquareRound',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumSquareRound']

# %%
fm.fontManager.addfont(path + '\\NanumGothic.ttf')

# %%
plt.rcParams['font.family'] = 'NanumGothic'
plt.plot([0,1,2,3], [0, 1, 4, 9])
plt.title('라인 플롯 - 나눔 스퀘어 폰트') 
plt.grid()
plt.show()
