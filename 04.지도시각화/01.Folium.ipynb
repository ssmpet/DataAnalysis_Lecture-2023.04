# %% [markdown]
# ### Folium 지도 시각화

# %% [markdown]
# - 설치: pip install folium

# %%
import folium
folium.__version__
# Out:
# '0.14.0'

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14) # Open Street Map
folium.Marker(
    location=[37.2949837, 127.043902], # wGS84 좌표계, 위도(latitude), 경도(longitude)
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fe779d46fe922553a1209ace97872ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fe779d46fe922553a1209ace97872ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fe779d46fe922553a1209ace97872ca = L.map(
#                 &quot;map_9fe779d46fe922553a1209ace97872ca&quot;,
#                 {
#                     center: [37.295, 127.045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6a21e45af70c010b179b57969ba8c37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9fe779d46fe922553a1209ace97872ca);
#
#
#             var marker_60e3ea8c35b81805fcfff7c99161a179 = L.marker(
#                 [37.2949837, 127.043902],
#                 {}
#             ).addTo(map_9fe779d46fe922553a1209ace97872ca);
#
#
#         var popup_bd91a533536d06c3e56c18bb3fb0bd84 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b78f3bbf80acc90cc2636691f7c7c871 = $(`&lt;div id=&quot;html_b78f3bbf80acc90cc2636691f7c7c871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 영통구 도청로 30&lt;/div&gt;`)[0];
#                 popup_bd91a533536d06c3e56c18bb3fb0bd84.setContent(html_b78f3bbf80acc90cc2636691f7c7c871);
#
#
#
#         marker_60e3ea8c35b81805fcfff7c99161a179.bindPopup(popup_bd91a533536d06c3e56c18bb3fb0bd84)
#         ;
#
#
#
#
#             marker_60e3ea8c35b81805fcfff7c99161a179.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14, tiles='Stamen Toner')
folium.Marker(
    location=[37.2949837, 127.043902], # wGS84 좌표계, 위도(latitude), 경도(longitude)
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07316de69012804d93bb7870430d476f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07316de69012804d93bb7870430d476f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07316de69012804d93bb7870430d476f = L.map(
#                 &quot;map_07316de69012804d93bb7870430d476f&quot;,
#                 {
#                     center: [37.295, 127.045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_349a7086534babd0785d81fafd69e90a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07316de69012804d93bb7870430d476f);
#
#
#             var marker_a23339d5abb5d81db629084dae2498fd = L.marker(
#                 [37.2949837, 127.043902],
#                 {}
#             ).addTo(map_07316de69012804d93bb7870430d476f);
#
#
#         var popup_a0324c5cba7de36305c3eea2dc5f4177 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_9d6960996f5d1f884595f2402ac2116a = $(`&lt;div id=&quot;html_9d6960996f5d1f884595f2402ac2116a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 영통구 도청로 30&lt;/div&gt;`)[0];
#                 popup_a0324c5cba7de36305c3eea2dc5f4177.setContent(html_9d6960996f5d1f884595f2402ac2116a);
#
#
#
#         marker_a23339d5abb5d81db629084dae2498fd.bindPopup(popup_a0324c5cba7de36305c3eea2dc5f4177)
#         ;
#
#
#
#
#             marker_a23339d5abb5d81db629084dae2498fd.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 경기도청, 장안구청, 팔달구청, 권선구청, 영통구청

# %%
# map = folium.Map(location=[37.2825, 127.0190], zoom_start=13)
map = folium.Map(location=[37.2710, 127.0154], zoom_start=13)

folium.Marker(
    location=[37.2949837, 127.043902], # wGS84 좌표계, 위도(latitude), 경도(longitude)
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청',
    icon=folium.Icon(
        color='purple', 
        icon_color='white',
        icon='glyphicon glyphicon-thumbs-up',
        prefix='glyphicon'
    )
).add_to(map)
folium.Marker(
    location=[37.30337225, 127.0096118], 
    popup=folium.Popup('경기도 수원시 장안구 송원로 101', max_width=200),
    icon=folium.Icon(color='green'),
    tooltip='장안구청'
).add_to(map)
folium.Marker(
    location=[37.28256171, 127.0190196],
    popup=folium.Popup('경기도 수원시 팔달구 창룡대로 23', max_width=200),
    tooltip='팔달구청',
    icon=folium.Icon(color='red', icon='cloud')
).add_to(map)
folium.Circle(
    radius=300,
    location=[37.25764489, 126.9719386],
    popup=folium.Popup('경기도 수원시 권선구 호매실로 12', max_width=200),
    tooltip='권선구청',
    color='crimson',
    fill=True
).add_to(map)
folium.CircleMarker(
    location=[37.2596127,127.0465469],
    radius=20,
    popup=folium.Popup('경기도 수원시 영통구 효원로 407', max_width=200),
    tooltip='영통구청',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(map)
title_html = '<h3 align="center" style="font-size:20px;">수원 소재 주요 관공서</h3>'
map.get_root().html.add_child(folium.Element(title_html))

folium.Marker(
    location=[37.2596127,127.0465469],
    icon=folium.Icon(color='green', popup_anchor=(0, 0)),
    
    # radius=20,
    # popup=folium.Popup('경기도 수원시 영통구 효원로 407', max_width=200),
    # tooltip='영통구청',
    # color='#3186cc',
    # fill=True,
    # fill_color='#3186cc'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_068e6508f44709a8b39721b7f1896f65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px;&quot;&gt;수원 소재 주요 관공서&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_068e6508f44709a8b39721b7f1896f65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_068e6508f44709a8b39721b7f1896f65 = L.map(
#                 &quot;map_068e6508f44709a8b39721b7f1896f65&quot;,
#                 {
#                     center: [37.271, 127.0154],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7858cdd531bd95dce04fd0ff47d4c1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_068e6508f44709a8b39721b7f1896f65);
#
#
#             var marker_38f02e16a7cca1b04c96d90b5a17312a = L.marker(
#                 [37.2949837, 127.043902],
#                 {}
#             ).addTo(map_068e6508f44709a8b39721b7f1896f65);
#
#
#             var icon_775bfc36279cdf17e5fe6af2c149526a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_38f02e16a7cca1b04c96d90b5a17312a.setIcon(icon_775bfc36279cdf17e5fe6af2c149526a);
#
#
#         var popup_24b34831ca2bf3374fb1d7acfe1bbb60 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_22218a2e5f423a8820193c7f128bd1ad = $(`&lt;div id=&quot;html_22218a2e5f423a8820193c7f128bd1ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 영통구 도청로 30&lt;/div&gt;`)[0];
#                 popup_24b34831ca2bf3374fb1d7acfe1bbb60.setContent(html_22218a2e5f423a8820193c7f128bd1ad);
#
#
#
#         marker_38f02e16a7cca1b04c96d90b5a17312a.bindPopup(popup_24b34831ca2bf3374fb1d7acfe1bbb60)
#         ;
#
#
#
#
#             marker_38f02e16a7cca1b04c96d90b5a17312a.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cdad1743ec0162c79f49de1b1851fa86 = L.marker(
#                 [37.30337225, 127.0096118],
#                 {}
#             ).addTo(map_068e6508f44709a8b39721b7f1896f65);
#
#
#             var icon_9bc0cd12674317b845626fa521acb4f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cdad1743ec0162c79f49de1b1851fa86.setIcon(icon_9bc0cd12674317b845626fa521acb4f9);
#
#
#         var popup_09b835cad84736618a6970a105353a8d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_02efce40be63085175b4e64563030bc9 = $(`&lt;div id=&quot;html_02efce40be63085175b4e64563030bc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 장안구 송원로 101&lt;/div&gt;`)[0];
#                 popup_09b835cad84736618a6970a105353a8d.setContent(html_02efce40be63085175b4e64563030bc9);
#
#
#
#         marker_cdad1743ec0162c79f49de1b1851fa86.bindPopup(popup_09b835cad84736618a6970a105353a8d)
#         ;
#
#
#
#
#             marker_cdad1743ec0162c79f49de1b1851fa86.bindTooltip(
#                 `&lt;div&gt;
#                      장안구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_44a7aaacbb4c9d57a1a59d4497d773a5 = L.marker(
#                 [37.28256171, 127.0190196],
#                 {}
#             ).addTo(map_068e6508f44709a8b39721b7f1896f65);
#
#
#             var icon_280449aee5f25ff346d8b802d3d2e82c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44a7aaacbb4c9d57a1a59d4497d773a5.setIcon(icon_280449aee5f25ff346d8b802d3d2e82c);
#
#
#         var popup_5853cc3bb8797b6b5233984e916a897d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_fffc5b878b1c829509fb75756d8e1d92 = $(`&lt;div id=&quot;html_fffc5b878b1c829509fb75756d8e1d92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 팔달구 창룡대로 23&lt;/div&gt;`)[0];
#                 popup_5853cc3bb8797b6b5233984e916a897d.setContent(html_fffc5b878b1c
