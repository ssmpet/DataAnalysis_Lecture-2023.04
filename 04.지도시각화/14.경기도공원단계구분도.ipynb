# %% [markdown]
# ### 경기도 내 공원 단계구분도

# %%
import numpy as np
import pandas as pd
import folium
import json

# %% [markdown]
# - 시군구별 공원면적 단계 구분도

# %%
gpark = pd.read_csv('data/경기도도시공원정보표준데이터.csv', encoding='euc-kr')
gpark.head(1)
# Out:
#           관리번호    공원명 공원구분 소재지도로명주소              소재지지번주소         위도
# 0  11170-00048  녹색소공원  소공원      NaN  서울특별시 용산구 효창동 287-6  37.539217  \
#
#            경도    공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설)
# 0  126.962694  1569.9          NaN          NaN          NaN          NaN  \
#
#   공원보유시설(기타시설)       지정고시일       관리기관명          전화번호     데이터기준일자   제공기관코드
# 0          NaN  2012-10-19  서울특별시 용산구청  02-2199-7605  2022-12-20  3020000  \
#
#        제공기관명
# 0  서울특별시 용산구

# %%
gpark = gpark[['소재지지번주소', '공원면적']]

gpark = gpark[gpark.소재지지번주소.str.find('경기도')>=0]   # 경기도만 추출

gpark.columns = ['주소', '공원면적']    # 컬럼명 변경
gpark.head()
# Out:
#                      주소    공원면적
# 212      경기도 이천시 중리동 15  2526.0
# 213     경기도 이천시 중리동 210  3830.0
# 214     경기도 이천시 창전동 408  1757.0
# 215  경기도 이천시 창전동 414-13  1650.0
# 216     경기도 이천시 창전동 423  1650.0

# %%
gpark.공원면적 = gpark.공원면적.astype(int)   # 면적 타입을 정수로
gpark.head()
# Out:
#                      주소  공원면적
# 212      경기도 이천시 중리동 15  2526
# 213     경기도 이천시 중리동 210  3830
# 214     경기도 이천시 창전동 408  1757
# 215  경기도 이천시 창전동 414-13  1650
# 216     경기도 이천시 창전동 423  1650

# %%
gpark.isna().sum()
# Out:
# 주소      0
# 공원면적    0
# dtype: int64

# %%
# 주소에서 시군구 이름 추출
g_list = []
for addr in gpark.주소:
    if addr.find('구 ') >=0:
        g_list.append(''.join(addr.split()[1:3]))
    else:
        g_list.append(addr.split()[1])

gpark['시군구'] = g_list
gpark.head()
# Out:
#                      주소  공원면적  시군구
# 212      경기도 이천시 중리동 15  2526  이천시
# 213     경기도 이천시 중리동 210  3830  이천시
# 214     경기도 이천시 창전동 408  1757  이천시
# 215  경기도 이천시 창전동 414-13  1650  이천시
# 216     경기도 이천시 창전동 423  1650  이천시

# %% [markdown]
# - 방법 2
# (lambda x.split()[1] if x.split([2][-1] != '구' else ''.join(x.split()[1:3]))

# %%
# 시군구별 공원면적 합 구하기
gpark = gpark.pivot_table('공원면적', '시군구', aggfunc='sum')
gpark.head()
# Out:
#             공원면적
# 시군구
# 가평군       511673
# 고양시덕양구   3287283
# 고양시일산동구  2722980
# 고양시일산서구   922486
# 과천시       315666

# %%
fname = 'data/경기도_geo_simple.json'   
geo_data = json.load(open(fname, encoding='utf-8'))

# %%
# 각 시군구별 평균 위치 구하기
def get_text_location(geo_str):
    gu_dict = {}
    for gu in geo_str['features']:
        for coord in gu['geometry']['coordinates']:
            # print(gu['properties']['name'])
            geo = np.array(coord)
            # 안산시단원구는 바닷가와 따로 떨어진 곳이 있어, 2개의 튜플 형태로 되어 있음. (data1, data2)
            # 그 중 앞의 값 즉, 육지값(data1)만으로만 계산
            # print(geo.ndim) 
            if geo.ndim == 3 :  
                gu_dict[gu['properties']['name']] = [np.mean(geo[0][:,1]), np.mean(geo[0][:,0])]
            else:
                gu_dict[gu['properties']['name']] = [np.mean(geo[:,1]), np.mean(geo[:,0])]  

    return gu_dict

gu_dict = get_text_location(geo_data)

# %%
# 지도에 시군구 이름 표시
def show_name(m_pop, m_dict, m_map):
    for name in m_pop.index:
        folium.map.Marker(
            location=m_dict[name],
            icon=folium.DivIcon(icon_size=(80,20), icon_anchor=(20,0),
                                html=f'<div style="font-size: 10pt">{name}</div>')
        ).add_to(m_map)

# %%
gmap = folium.Map([37.4, 127.1], zoom_start=9, tiles='Stamen Toner')
# gmap = folium.Map([37.4, 127.1], zoom_start=9)

folium.Choropleth(
    geo_data=geo_data,
    data=gpark.공원면적,
    columns=[gpark.index, gpark.공원면적],
    fill_color='YlOrRd',
    key_on='properties.name'
).add_to(gmap)

show_name(gpark, gu_dict, gmap)

title_html = '<h3 align="center" style="font-size: 20px;">경기도 시군구별 공원면적</h3>'  
gmap.get_root().html.add_child(folium.Element(title_html))

gmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eec014f251bc3966574b63649c3b0683 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size: 20px;&quot;&gt;경기도 시군구별 공원면적&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eec014f251bc3966574b63649c3b0683&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eec014f251bc3966574b63649c3b0683 = L.map(
#                 &quot;map_eec014f251bc3966574b63649c3b0683&quot;,
#                 {
#                     center: [37.4, 127.1],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c49d69c38e5bf42df0db0c2533b202e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eec014f251bc3966574b63649c3b0683);
#
#
#             var choropleth_4f9c3975099f9dc77e83e7a3a6cf4cdf = L.featureGroup(
#                 {}
#             ).addTo(map_eec014f251bc3966574b63649c3b0683);
#
#
#         function geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;31270&quot;: case &quot;31260&quot;: case &quot;31210&quot;: case &quot;31193&quot;: case &quot;31192&quot;: case &quot;31180&quot;: case &quot;31170&quot;: case &quot;31140&quot;: case &quot;31103&quot;: case &quot;31030&quot;: case &quot;31022&quot;: case &quot;31021&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;31240&quot;: case &quot;31070&quot;: case &quot;31023&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;31230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;31200&quot;: case &quot;31191&quot;: case &quot;31101&quot;: case &quot;31092&quot;: case &quot;31091&quot;: case &quot;31080&quot;: case &quot;31060&quot;: case &quot;31053&quot;: case &quot;31014&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;31150&quot;: case &quot;31130&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96 = L.geoJson(null, {
#                 onEachFeature: geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96_onEachFeature,
#
#                 style: geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96_styler,
#         });
#
#         function geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96_add (data) {
#             geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96
#                 .addData(data)
#                 .addTo(choropleth_4f9c3975099f9dc77e83e7a3a6cf4cdf);
#         }
#             geo_json_6dd8d203f8e9d6a4f3a452b305cdbd96_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.58166701442097, 37.63033393389168], [127.60450569091653, 37.648548552427314], [127.62972032693943, 37.63983122973888], [127.65553070991882, 37.61954565135447], [127.69869383868397, 37.59757031454811], [127.7102810556826, 37.58360128682645], [127.75614914198108, 37.589477424718204], [127.76838776707211, 37.580178216134605], [127.79492564827493, 37.58252978378627], [127.81507964099751, 37.5618389022189], [127.85162286006927, 37.55037340096326], [127.8445769305193, 37.53621789699497], [127.80855972024105, 37.53220450961153], [127.77611527652192, 37.50328615763377], [127.77664798308412, 37.4888363

# %% [markdown]
# - 시군구별 인당 공원면적 단계 구분도

# %%
# 경기도 시군구별 인구수 구하기
except_city = ['경기도 수원시', '경기도 고양시', '경기도 용인시', '경기도 성남시', '경기도 안산시', '경기도 안양시']


pop = pd.read_csv('../02.Pandas/data/주민등록인구집계현황.csv', encoding='euc-kr')
pop = pop[['행정구역구분명', '행정구역명', '총 인구수']]
pop = pop[((pop.행정구역구분명 == '시군') | (pop.행정구역구분명 == '구')) & ~(pop['행정구역명'].str.strip().isin(except_city))]
pop = pop[['행정구역명', '총 인구수']]
pop.head()
# Out:
#             행정구역명   총 인구수
# 1        경기도 가평군    62197
# 9    경기도 고양시 덕양구   487874
# 31  경기도 고양시 일산동구   296590
# 44  경기도 고양시 일산서구   290738
# 56       경기도 과천시    77775

# %%
pop['시군구'] = pop.행정구역명.apply(lambda x: ''.join(x.split()[1:]))
pop.head()
# Out:
#             행정구역명   총 인구수      시군구
# 1        경기도 가평군    62197      가평군
# 9    경기도 고양시 덕양구   487874   고양시덕양구
# 31  경기도 고양시 일산동구   296590  고양시일산동구
# 44  경기도 고양시 일산서구   290738  고양시일산서구
# 56       경기도 과천시    77775      과천시

# %%
pop = pop[['시군구', '총 인구수']]
pop.set_index('시군구', inplace=True)
pop.columns = ['인구']
pop.head()
# Out:
#              인구
# 시군구
# 가평군       62197
# 고양시덕양구   487874
# 고양시일산동구  296590
# 고양시일산서구  290738
# 과천시       77775

# %%
ggpark = pd.merge(gpark, pop, left_index=True, right_index=True)
ggpark.head()
# Out:
#             공원면적      인구
# 시군구
# 가평군       511673   62197
# 고양시덕양구   3287283  487874
# 고양시일산동구  2722980  296590
# 고양시일산서구   922486  290738
# 과천시       315666   77775

# %% [markdown]
# - 또 다른 방법으로 조인
#
#     df는 index, pop은 '시군구' 컬럼으로 조인
#
#     df  = df.merge(pop, left_index=True, right_on='시군구')

# %%
ggpark['인당공원면적'] = ggpark.공원면적 / ggpark.인구

# %%
ggpark.head()
# Out:
#             공원면적      인구    인당공원면적
# 시군구
# 가평군       511673   62197  8.226651
# 고양시덕양구   3287283  487874  6.737975
# 고양시일산동구  2722980  296590  9.180957
# 고양시일산서구   922486  290738  3.172912
# 과천시       315666   77775  4.058708

# %%
gmap = folium.Map([37.4, 127.1], zoom_start=9, tiles='Stamen Toner')

folium.Choropleth(
    geo_data=geo_data,
    data=ggpark.인당공원면적,
    columns=[ggpark.index, ggpark.인당공원면적],
    fill_color='YlOrRd',
    key_on='properties.name'
).add_to(gmap)

show_name(ggpark, gu_dict, gmap)

title_html = '<h3 align="center" style="font-size: 20px;">경기도 시군구별 인당 공원면적율</h3>'  
gmap.get_root().html.add_child(folium.Element(title_html))
gmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c492b0fb0ec0f5fe7026b8bb48b23779 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size: 20px;&quot;&gt;경기도 시군구별 인당 공원면적율&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c492b0fb0ec0f5fe7026b8bb48b23779&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c492b0fb0ec0f5fe7026b8bb48b23779 = L.map(
#                 &quot;map_c492b0fb0ec0f5fe7026b8bb48b23779&quot;,
#                 {
#                     center: [37.4, 127.1],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbf79c3d4471284bce4f219d4633c366 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c492b0fb0ec0f5fe7026b8bb48b23779);
#
#
#             var choropleth_6c9fa81dc4792012cadc508184ac6a3f = L.featureGroup(
#                 {}
#             ).addTo(map_c492b0fb0ec0f5fe7026b8bb48b23779);
#
#
#         function geo_json_83ef5f3fd1aaa78d30db5af7186d65a0_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;31270&quot;: case &quot;31260&quot;: case &quot;31230&quot;: case &quot;31210&quot;: case &quot;31191&quot;: case &quot;31170&quot;: case &quot;31140&quot;: case &quot;31103&quot;: case &quot;31092&quot;: case &quot;31091&quot;: case &quot;31070&quot;: case &quot;31060&quot;: case &quot;31022&quot;: case &quot;31021&quot;: case &quot;31014&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;31080&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;31023&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_83ef5f3fd1aaa78d30db5af7186d65a0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_83ef5f3fd1aaa78d30db5af7186d65a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_83ef5f3fd1aaa78d30db5af7186d65a0_onEachFeature,
#
#                 style: geo_json_83ef5f3fd1aaa78d30db5af7186d65a0_styler,
#         });
#
#         function geo_json_83ef5f3fd1aaa78d30db5af7186d65a0_add (data) {
#             geo_json_83ef5f3fd1aaa78d30db5af7186d65a0
#                 .addData(data)
#                 .addTo(choropleth_6c9fa81dc4792012cadc508184ac6a3f);
#         }
#             geo_json_83ef5f3fd1aaa78d30db5af7186d65a0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.58166701442097, 37.63033393389168], [127.60450569091653, 37.648548552427314], [127.62972032693943, 37.63983122973888], [127.65553070991882, 37.61954565135447], [127.69869383868397, 37.59757031454811], [127.7102810556826, 37.58360128682645], [127.75614914198108, 37.589477424718204], [127.76838776707211, 37.580178216134605], [127.79492564827493, 37.58252978378627], [127.81507964099751, 37.5618389022189], [127.85162286006927, 37.55037340096326], [127.8445769305193, 37.53621789699497], [127.80855972024105, 37.53220450961153], [127.77611527652192, 37.50328615763377], [127.77664798308412, 37.48883635932707], [127.79833492163134, 37.460500237870505], [127.80397287036232, 37.432516049235865], [127.77952402154285, 37.368441789396854], [127.76165381178268, 37.36421926003675], [127.70347417929173, 37.371054026073324], [127.71071536074867, 37.40736583858037], [127.66976823475012, 37.40884431255766], [127.6491838950862, 37.402042953108506], [127.63754040237271, 37.41065607591271], [127.60528700481163, 37.416969769508924], [127.53910572062166, 37.40849283821634], [127.52501209957308, 37.43192043868044], [127.51015267026155, 37.43699555518635], [127.4817900304572, 37.42084413829662], [127.4250053080982, 37.43669952587185], [127.4027673988021

# %% [markdown]
# - 데이터 프레임 합성 방향
#     - 인구데이터 + 공원데이터 합성
#     - 합성된 데이터와 지도 데이터 조인
#
#
#     - 공원데이터에서 빈('-') 컬럼을 추가
#         - park['시군구'] = ['-'] * len(park)
#         - 소재지번주소 열에서 시군구만 추출하기 (pop 데이터프레임에서)
